# %%
pip install boto3
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
aws configure
# Out:
#   Cell In[5], line 1
#     aws configure
#         ^
# SyntaxError: invalid syntax
